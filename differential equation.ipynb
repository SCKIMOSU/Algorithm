# %% [markdown]
# <a href="https://colab.research.google.com/github/SCKIMOSU/Algorithm/blob/master/differential%20equation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sympy as sp
x=sp.Symbol('x')
fx=x**2+4*x+3
print("f(x)= ", sp.factor(fx))
# Out:
# f(x)=  (x + 1)*(x + 3)
# f(x)= 6*x + 2
# f(x)= cos(x)

# %%
import sympy as sp
x=sp.Symbol('x')
fx=3*x**2+2*x+1
print('f(x)=', sp.diff(fx,x))

import sympy as sp
x=sp.Symbol('x')
fx=sp.sin(x)
print('f(x)=', sp.diff(fx,x))
# Out:
# f(x)= 6*x + 2
# f(x)= cos(x)

# %%
import sympy as sp
x=sp.Symbol('x')
fx=sp.tanh(x)
print('f(x)=', sp.diff(fx,x))
# Out:
# f(x)= 1 - tanh(x)**2

# %%
import numpy as np

def tanh(x, diff=False):
  if diff:
    return (1+tanh(x))*(1-tanh(x))
  else:
    return np.tanh(x)

# %%
import sympy as sp
x=sp.Symbol('x')
# 9.8-0.25/68*v**2-diff(v)=0 
sp.dsolve(9.8-0.25/68*x**2-x.diff())
#fx=sp.tanh(x)
#print('f(x)=', sp.diff(fx,x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-9bf7a725c67d> in <module>()
#       2 x=sp.Symbol('x')
#       3 # 9.8-0.25/68*v**2-diff(v)=0
# ----> 4 sp.dsolve(9.8-0.25/68*x**2-x.diff())
#       5 #fx=sp.tanh(x)
#       6 #print('f(x)=', sp.diff(fx,x))
#
# /usr/local/lib/python3.7/dist-packages/sympy/solvers/ode/ode.py in dsolve(eq, func, hint, simplify, ics, xi, eta, x0, n, **kwargs)
#     629         hints = _desolve(eq, func=func,
#     630             hint=hint, simplify=True, xi=xi, eta=eta, type='ode', ics=ics,
# --> 631             x0=x0, n=n, **kwargs)
#     632         eq = hints.pop('eq', eq)
#     633         all_ = hints.pop('all', False)
#
# /usr/local/lib/python3.7/dist-packages/sympy/solvers/deutils.py in _desolve(eq, func, hint, ics, simplify, prep, **kwargs)
#     180     # preprocess the equation and find func if not given
# ...

# %%
import sympy as sp
x=sp.Symbol('x')
sp.dsolve(y(x).diff()-cos(x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-47d0a3d9e654> in <module>()
#       1 import sympy as sp
#       2 x=sp.Symbol('x')
# ----> 3 sp.dsolve(y(x).diff()-cos(x))
#
# NameError: name 'y' is not defined

# %%
from sympy import *

x, y, z, t = symbols('x y z t')
f, g, h = symbols('f, g, h', cls=Function)

init_printing()
# %matplotlib inline 
y = symbols('y', cls=Function)
print(y(t))
deq = Eq( y(t).diff(t), -2*y(t) )
print(deq)
dsolve(deq, y(t))
# Out:
# y(t)
# Eq(Derivative(y(t), t), -2*y(t))
#            -2⋅t
# y(t) = C₁⋅ℯ

# %%
from sympy import *

x, y, z, t = symbols('x y z t')
f, g, h = symbols('f, g, h', cls=Function)

init_printing()
# %matplotlib inline 
y = symbols('y', cls=Function)
print(y(t))
deq = Eq( y(t).diff(t), y(t)**2 )
print(deq)
dsolve(deq, y(t))
# Out:
# y(t)
# Eq(Derivative(y(t), t), y(t)**2)
#         -1
# y(t) = ──────
#        C₁ + t

# %%
from sympy import *

x, y, z, gr, cd, m, t = symbols('x y z gr cd m t')
f, g, h = symbols('f, g, h', cls=Function)

init_printing()
# %matplotlib inline 
y = symbols('y', cls=Function)
print(y(t))
deq = Eq( y(t).diff(t), gr-cd/m*y(t)**2 )
print(deq)
dsolve(deq, y(t))
# Out:
# y(t)
# Eq(Derivative(y(t), t), -cd*y(t)**2/m + gr)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/sympy/core/assumptions.py in getit(self)
#     453         try:
# --> 454             return self._assumptions[fact]
#     455         except KeyError:
#
# KeyError: 'finite'
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
# <ipython-input-21-639d0a5afc6f> in <module>()
#      10 deq = Eq( y(t).diff(t), gr-cd/m*y(t)**2 )
#      11 print(deq)
# ---> 12 dsolve(deq, y(t))
#
# /usr/local/lib/python3.7/dist-packages/sympy/solvers/ode/ode.py in dsolve(eq, func, hint, simplify, ics, xi, eta, x0, n, **kwargs)
#     662             # The key 'hint' stores the hint needed to be solved for.
#     663             hint = hints['hint']
# ...

# %%
from sympy import *
x, y, z = symbols('x y z')
init_printing(use_unicode=True)
k, m, n = symbols('k m n', integer=True)
f, g, h = symbols('f g h', cls=Function)
simplify(sin(x)**2 + cos(x)**2)
simplify((x**3 + x**2 - x - 1)/(x**2 + 2*x + 1))
# Out:
# x - 1

# %%
import numpy as np
import matplotlib.pyplot as plt


def f(x):
    return x**3 - 3 * x**2 + x

x = np.linspace(-1, 3, 400)
y = f(x)

plt.plot(x, y)
plt.plot(0, 0, 'ro')
plt.plot(x, x, 'r:')
plt.plot(1, -1, 'go')
plt.plot(x, (3*1**2-6*1+1)*(x-1)-1, 'g--')

plt.xlim(-3.5, 5.5)
plt.ylim(-4, 2)
plt.xticks(np.arange(-3, 6))
plt.yticks(np.arange(-4, 2))

plt.annotate('', xy=(1, 0), xytext=(0, 0), arrowprops=dict(facecolor='gray'))
plt.annotate('', xy=(1, 1), xytext=(1, 0), arrowprops=dict(facecolor='gray'))

plt.annotate('', xy=(2, -1), xytext=(1, -1), arrowprops=dict(facecolor='gray'))
plt.annotate('', xy=(2, -3), xytext=(2, -1), arrowprops=dict(facecolor='gray'))

plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("함수의 기울기")
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54632 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50872 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

def fprime(x):
    return 3 * x ** 2 - 6 * x + 1

# 2차 방정식의 근
x1, x2 = np.roots([3, -6, 1]) 

x = np.linspace(-1, 3, 400)

plt.figure(figsize=(10, 7))
plt.subplot(211)
plt.plot(x, f(x))
plt.xlim(-2, 4)
plt.xticks(np.arange(-1, 4))
plt.yticks(np.arange(-5, 4))
plt.xlabel('x')
plt.title('함수 f(x)')
plt.axvline(x1, c="b", ls="--")
plt.axvline(x2, c="b", ls="--")

plt.subplot(212)
plt.plot(x, fprime(x))
plt.xlim(-2, 4)
plt.xticks(np.arange(-1, 4))
plt.yticks(np.arange(-3, 11))
plt.xlabel('x')
plt.title("도함수 f'(x)")
plt.axhline(0, c="r", ls="--")
plt.axvline(x1, c="b", ls="--")
plt.axvline(x2, c="b", ls="--")

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54632 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54632 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...
